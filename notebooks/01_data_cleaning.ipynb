# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
education_unemployed = pd.read_csv("../data/Data_africa_education_unemployed.csv")
education_inactive = pd.read_csv("../data/Data_africa_education_inactive.csv")
rural_urban = pd.read_csv("../data/Data_employed_rural_urban.csv")

# %%
dataset ={
    'unemployed' : education_unemployed,
    'inactive' : education_inactive,
    'urban': rural_urban
}

# %%
for name, df in dataset.items():
    print("Analyse de :", name)
    print("\n notre head est \n", df.tail())
    #print("\n notre describe est\n",df.describe(include='all'))
# Out:
# Analyse de : unemployed
#
#  notre head est
#        ccode  year          edu_ilo age_group gender  share_unemp  share_inact
# 17815   ZWE  2021  Upper secondary     55-64   male      0.04500      0.18205
# 17816   ZWE  2022  Upper secondary     55-64   male      0.04425      0.16409
# 17817   ZWE  2023  Upper secondary     55-64   male      0.02660      0.16446
# 17818   ZWE  2024  Upper secondary     55-64   male      0.06226      0.20576
# 17819   ZWE  2025  Upper secondary     55-64   male      0.06226      0.20576
# Analyse de : inactive
#
#  notre head est
#        ccode  year gender age_group          edu_ilo   neet_fc
# 17815   ZWE  2021   Male     55-64  Upper Secondary  0.299965
# 17816   ZWE  2022   Male     55-64  Upper Secondary  0.359923
# 17817   ZWE  2023   Male     55-64  Upper Secondary  0.353150
# 17818   ZWE  2024   Male     55-64  Upper Secondary  0.476936
# 17819   ZWE  2025   Male     55-64  Upper Secondary  0.476936
# Analyse de : urban
#
#  notre head est
#         ccode  year gender  age age_group      status    geo  pop_emp_geo
# 466395   ZWE  2025   male   64     55-64  unemployed  urban        798.0
# 466396   ZWE  2025   male   64     55-64    inactive  rural       2190.0
# 466397   ZWE  2025   male   64     55-64    inactive  urban        839.0
# 466398   ZWE  2025   male   64     55-64     student  rural          0.0
# 466399   ZWE  2025   male   64     55-64     student  urban          0.0
