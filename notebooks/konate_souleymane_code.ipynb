# %%
import pandas as pd

# %%
df = pd.read_csv("../data/Data_africa_education_unemployed.csv")
sd = pd.read_csv("../data/Data_africa_education_inactive.csv")
az = pd.read_csv("../data/Data_employed_rural_urban.csv")

# %%
df
# Out:
#       ccode  year            edu_ilo age_group  gender  share_unemp  \
# 0       AGO  2015  Less than primary     15-24  female     0.056506
# 1       AGO  2016  Less than primary     15-24  female     0.054342
# 2       AGO  2017  Less than primary     15-24  female     0.052178
# 3       AGO  2018  Less than primary     15-24  female     0.050014
# 4       AGO  2019  Less than primary     15-24  female     0.047850
# ...     ...   ...                ...       ...     ...          ...
# 17815   ZWE  2021    Upper secondary     55-64    male     0.045000
# 17816   ZWE  2022    Upper secondary     55-64    male     0.044250
# 17817   ZWE  2023    Upper secondary     55-64    male     0.026600
# 17818   ZWE  2024    Upper secondary     55-64    male     0.062260
# 17819   ZWE  2025    Upper secondary     55-64    male     0.062260
#
#        share_inact
# 0         0.613708
# 1         0.532776
# 2         0.451844
# 3         0.370912
# 4         0.289980
# ...            ...
# ...
